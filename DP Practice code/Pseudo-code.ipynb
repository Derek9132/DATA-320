# %% [markdown]
# **Policy evaluation**

# %% [markdown]
# ![image.png](attachment:cc9ca2cd-6a5c-4421-a43b-865eeb4fa397.png)!

# %% [markdown]
# **Policy improvement**

# %% [markdown]
# ![PIM.jpg](attachment:bb1d8f14-e017-4322-bf14-a5d4f60fbbb7.jpg)

# %% [markdown]
# **Policy iteration**

# %% [markdown]
# ![PI.jpg](attachment:9f738d2b-e735-4114-9548-560e419ae9bf.jpg)

# %% [markdown]
# **Value iteration**

# %% [markdown]
# ![VI.jpg](attachment:37c1ca2a-f56f-4200-a305-3c35ff6d8de8.jpg)
